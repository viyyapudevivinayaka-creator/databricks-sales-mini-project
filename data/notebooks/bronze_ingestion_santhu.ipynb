# %% [markdown]
# # bronze layer ingestion for sales data csv

# %%
#/Volumes/workspace/default/santhu_volume/sales.csv

df_sales = spark.read.csv("/Volumes/workspace/default/santhu_volume/sales.csv", inferSchema = True, header = True)

# %%
display (df_sales)

# %%
df_sales.write.saveAsTable("sales")
